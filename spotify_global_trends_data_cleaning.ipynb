# %%
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np

# %%
spotify_database = pd.read_csv(
    "spotify_global_trends_2026 - spotify_global_trends_final.csv", 
    index_col=0)
spotify_dtb_df = pd.DataFrame(spotify_database)

# %%
spotify_dtb_df
# Out:
#                              artist_name   streams  stream_change      7day  \
# track_name
# SWIM                                 BTS  11273830       -3370522  25918182
# Body to Body                         BTS   6815694       -4369341  18000729
# Babydoll                    Dominic Fike   5733862         178968  36599831
# Hooligan                             BTS   5338608       -3396855  14074071
# FYA                                  BTS   5196767       -2873904  13267438
# ...                                  ...       ...            ...       ...
# The Chain - 2004 Remaster  Fleetwood Mac   1210598         -79537   8817306
# Love On The Brain                Rihanna   1203160         -69820   7439269
# Sign of the Times           Harry Styles   1198929        -121566   3816744
# Sorry                      Justin Bieber   1192146         -86760   7346804
# Life Goes On                         BTS   1191777         -76127   8979038
#
# ...

# %%
spotify_dtb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 178 entries, SWIM to Life Goes On
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   artist_name          178 non-null    object
#  1   streams              178 non-null    int64
#  2   stream_change        178 non-null    int64
#  3   7day                 178 non-null    int64
#  4   genre                178 non-null    object
#  5   country              178 non-null    object
#  6   pos                  178 non-null    int64
#  7   days                 178 non-null    int64
#  8   viral_score          178 non-null    int64
#  9   trend                178 non-null    object
#  10  popularity_category  178 non-null    object
#  11  longevity            178 non-null    object
# dtypes: int64(6), object(6)
# memory usage: 18.1+ KB

# %%
spotify_dtb_df.loc['Babydoll', 'country'] = "US"
spotify_dtb_df.loc['Sign of the Times', 'country'] = "UK"
spotify_dtb_df
# Out:
#                              artist_name   streams  stream_change      7day  \
# track_name
# SWIM                                 BTS  11273830       -3370522  25918182
# Body to Body                         BTS   6815694       -4369341  18000729
# Babydoll                    Dominic Fike   5733862         178968  36599831
# Hooligan                             BTS   5338608       -3396855  14074071
# FYA                                  BTS   5196767       -2873904  13267438
# ...                                  ...       ...            ...       ...
# The Chain - 2004 Remaster  Fleetwood Mac   1210598         -79537   8817306
# Love On The Brain                Rihanna   1203160         -69820   7439269
# Sign of the Times           Harry Styles   1198929        -121566   3816744
# Sorry                      Justin Bieber   1192146         -86760   7346804
# Life Goes On                         BTS   1191777         -76127   8979038
#
# ...

# %%
spotify_dtb_df = spotify_dtb_df.rename(columns={
    "artist_name" : "artist",
    "pos" : "position",
    "days" : "days_on_chart",
    '7day': 'streams_7day'
})

spotify_dtb_df
# Out:
#                                   artist   streams  stream_change  \
# track_name
# SWIM                                 BTS  11273830       -3370522
# Body to Body                         BTS   6815694       -4369341
# Babydoll                    Dominic Fike   5733862         178968
# Hooligan                             BTS   5338608       -3396855
# FYA                                  BTS   5196767       -2873904
# ...                                  ...       ...            ...
# The Chain - 2004 Remaster  Fleetwood Mac   1210598         -79537
# Love On The Brain                Rihanna   1203160         -69820
# Sign of the Times           Harry Styles   1198929        -121566
# Sorry                      Justin Bieber   1192146         -86760
# Life Goes On                         BTS   1191777         -76127
#
#                            streams_7day            genre country  position  \
# track_name
# ...

# %%
spotify_dtb_df.iloc[6:51]
spotify_dtb_df.iloc[6:7, 5:6] = "UK"
spotify_dtb_df.iloc[6:51]
# Out:
#                                                                artist  \
# track_name
# Stateside + Zara Larsson (w/ Zara Larsson)             PinkPantheress
# Aliens                                                            BTS
# 2                                                                 BTS
# Like Animals                                                      BTS
# Merry Go Round                                                    BTS
# they don’t know ’bout us                                          BTS
# Man I Need                                                Olivia Dean
# DtMF                                                        Bad Bunny
# End of Beginning                                                  Djo
# Risk It All                                                Bruno Mars
# One More Night                                                    BTS
# So Easy (To Fall In Love)                                 Olivia Dean
# ...

# %%
spotify_dtb_df.loc['White Keys', 'country'] = "US"
spotify_dtb_df.loc['American Girls', 'country'] = "US"
spotify_dtb_df.loc['iloveitiloveitiloveit', 'genre'] = "Indie Pop"
spotify_dtb_df.loc['EoO', 'genre'] = "Reggaeton"
spotify_dtb_df.loc['Risk It All', 'genre'] = "Pop"
spotify_dtb_df.loc['White Keys', 'genre'] = "Indie Pop"
spotify_dtb_df.iloc[6:51]
# Out:
#                                                                artist  \
# track_name
# Stateside + Zara Larsson (w/ Zara Larsson)             PinkPantheress
# Aliens                                                            BTS
# 2                                                                 BTS
# Like Animals                                                      BTS
# Merry Go Round                                                    BTS
# they don’t know ’bout us                                          BTS
# Man I Need                                                Olivia Dean
# DtMF                                                        Bad Bunny
# End of Beginning                                                  Djo
# Risk It All                                                Bruno Mars
# One More Night                                                    BTS
# So Easy (To Fall In Love)                                 Olivia Dean
# ...

# %%
spotify_dtb_df[51:101]
spotify_dtb_df.loc[spotify_dtb_df['country'] == 'England', 'country'] = 'UK'

mexico_cities = ['Culiacán', 'Monterrey']
spotify_dtb_df.loc[spotify_dtb_df['country'].isin(mexico_cities), 'country'] = 'MX'
spotify_dtb_df.loc['E85', 'genre'] = 'Trap'

great_britain = ['UK', 'England']
spotify_dtb_df.loc[spotify_dtb_df['country'].isin(great_britain), 'country'] = "GB"

spotify_dtb_df.loc['FEVER DREAM', 'genre'] = "Pop"
spotify_dtb_df.loc['Gabriela', 'genre'] = "Pop"
spotify_dtb_df.loc['La Plena - W Sound 05 (w/ Beéle, Ovy On The Drums)', 'genre'] = "Reggaeton"
spotify_dtb_df.loc['Marlboro Rojo', 'genre'] = 'Regional Mexican'
spotify_dtb_df.loc['Alex Warren', 'genre'] = 'Pop'
spotify_dtb_df.loc['The Visitor', 'artist'] = 'Sienna Spiro'
spotify_dtb_df.loc['Si Antes Te Hubiera Conocido', 'artist'] = 'Karol G'
spotify_dtb_df[51:101]
# Out:
#                                                                  artist  \
# track_name
# Sweater Weather                                       The Neighbourhood
# One Dance (w/ Wizkid, Kyla)                                       Drake
# Rein Me In (w/ Olivia Dean)                                  Sam Fender
# Creep                                                         Radiohead
# Opalite                                                    Taylor Swift
# FEVER DREAM                                                 Alex Warren
# dopamina (w/ Tito Double P)                                  Peso Pluma
# E85                                                         Don Toliver
# That's What I Like                                           Bruno Mars
# Dracula                                                     Tame Impala
# Dreams - 2004 Remaster                                    Fleetwood Mac
# Gabriela                                                        KATSEYE
# ...

# %%
pd.set_option('display.max_rows', 500)
country_df = spotify_dtb_df[['genre']]
country_df
# Out:
#                                                                      genre
# track_name
# SWIM                                                                 K-Pop
# Body to Body                                                         K-Pop
# Babydoll                                                   Alternative Pop
# Hooligan                                                             K-Pop
# FYA                                                                  K-Pop
# NORMAL                                                               K-Pop
# Stateside + Zara Larsson (w/ Zara Larsson)                       Uk Garage
# Aliens                                                               K-Pop
# 2                                                                    K-Pop
# Like Animals                                                         K-Pop
# Merry Go Round                                                       K-Pop
# ...
